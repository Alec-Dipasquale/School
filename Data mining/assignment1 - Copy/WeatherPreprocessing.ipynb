# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
from pandas import Series, DataFrame

# %%
#read data
weather_data = pd.read_csv("./data/Weather/games.csv", sep=",")
game_data = pd.read_csv("./data/Weather/games_weather.csv", sep=",")
stadium_data = pd.read_csv("./data/Weather/stadium_coordinates.csv", sep=",")
game_data.head()
# Out:
#       game_id     Source  DistanceToStation     TimeMeasure  Temperature  \
# 0  2000090300  Meteostat               3.79  9/3/2000 12:00        80.96
# 1  2000090300  Meteostat               3.79  9/3/2000 13:00        80.96
# 2  2000090300  Meteostat               3.79  9/3/2000 14:00        82.94
# 3  2000090300  Meteostat               3.79  9/3/2000 15:00        80.06
# 4  2000090300  Meteostat               3.79  9/3/2000 16:00        75.02
#
#    DewPoint  Humidity  Precipitation  WindSpeed  WindDirection  Pressure  \
# 0     73.04      77.0          0.000       3.36          200.0   29.8902
# 1     73.04      77.0          0.000       5.84          300.0   29.8784
# 2     73.04      72.0          0.000       5.84          260.0   29.8696
# 3     74.12      82.0          0.000       3.36          180.0   29.8578
# 4     75.02     100.0          0.728       4.72          280.0   29.8519
#
#   EstimatedCondition
# 0              Clear
# 1              Clear
# ...

# %%
game_data.tail()
# Out:
#           game_id     Source  DistanceToStation     TimeMeasure  Temperature  \
# 37150  2021020700  Meteostat                NaN  2/7/2021 20:00        60.98
# 37151  2021020700  Meteostat                NaN  2/7/2021 21:00        59.00
# 37152  2021020700  Meteostat                NaN  2/7/2021 22:00        57.02
# 37153  2021020700  Meteostat                NaN  2/7/2021 23:00        57.02
# 37154  2021020700  Meteostat                NaN   2/8/2021 0:00        57.02
#
#        DewPoint  Humidity  Precipitation  WindSpeed  WindDirection  Pressure  \
# 37150     51.98      72.0            0.0       8.08          320.0   30.0408
# 37151     53.24      81.0            0.0       5.59          350.0   30.0645
# 37152     54.14      90.0            0.0       6.84          350.0   30.0910
# 37153     54.14      90.0            0.0       5.59          340.0   30.1029
# 37154     54.14      90.0            0.0       6.84           20.0   30.1088
#
#       EstimatedCondition
# ...

# %%
weather_data.head()
# Out:
#       game_id  Season              StadiumName   TimeStartGame  \
# 0  2000090300    2000           Giants Stadium  9/3/2000 13:00
# 1  2000090301    2000     Three Rivers Stadium  9/3/2000 13:00
# 2  2000090302    2000               FedExField  9/3/2000 13:00
# 3  2000090303    2000        U.S. Bank Stadium  9/3/2000 12:00
# 4  2000090304    2000  Mercedes-Benz Superdome  9/3/2000 12:00
#
#       TimeEndGame  TZOffset
# 0  9/3/2000 16:40        -4
# 1  9/3/2000 15:58        -4
# 2  9/3/2000 16:04        -4
# 3  9/3/2000 15:08        -5
# 4  9/3/2000 15:12        -5

# %%
weather_data.tail()
# Out:
#          game_id  Season              StadiumName    TimeStartGame  \
# 5588  2021011700    2020        Arrowhead Stadium  1/17/2021 14:05
# 5589  2021011701    2020  Mercedes-Benz Superdome  1/17/2021 17:40
# 5590  2021012400    2020            Lambeau Field  1/24/2021 14:05
# 5591  2021012401    2020        Arrowhead Stadium  1/24/2021 17:40
# 5592  2021020700    2020    Raymond James Stadium   2/7/2021 18:30
#
#           TimeEndGame  TZOffset
# 5588  1/17/2021 17:06        -6
# 5589  1/17/2021 20:52        -6
# 5590  1/24/2021 17:19        -6
# 5591  1/24/2021 21:06        -6
# 5592   2/7/2021 22:05        -5

# %%
stadium_data.head()
# Out:
#                StadiumName HomeTeam     RoofType   Longitude   Latitude  \
# 0                Alamodome       NO       Indoor  -98.478889  29.416944
# 1        Allegiant Stadium       LV       Indoor -115.183722  36.090750
# 2        Arrowhead Stadium       KC      Outdoor  -94.483889  39.048889
# 3             AT&T Stadium      DAL  Retractable  -97.092778  32.747778
# 4  Bank of America Stadium      CAR      Outdoor  -80.852778  35.225833
#
#    StadiumAzimuthAngle
# 0                  0.0
# 1                  0.0
# 2                316.3
# 3                 68.0
# 4                322.4

# %%
stadium_data.tail()
# Out:
#                   StadiumName    HomeTeam RoofType  Longitude   Latitude  \
# 54  Tottenham Hotspur Stadium   Tottenham  Outdoor  -0.066389  51.604444
# 55         Twickenham Stadium  Twickenham  Outdoor  -0.341667  51.456111
# 56          U.S. Bank Stadium         MIN   Indoor -93.258056  44.973889
# 57           Veterans Stadium         PHI  Outdoor -75.171111  39.906667
# 58            Wembley Stadium     Wembley  Outdoor  -0.279722  51.555833
#
#     StadiumAzimuthAngle
# 54                  0.0
# 55                324.8
# 56                309.9
# 57                 90.0
# 58                 90.0

# %%
game_data['Temperature']
# Out:
# 0        80.96
# 1        80.96
# 2        82.94
# 3        80.06
# 4        75.02
#          ...
# 37150    60.98
# 37151    59.00
# 37152    57.02
# 37153    57.02
# 37154    57.02
# Name: Temperature, Length: 37155, dtype: float64

# %%
plt.plot(game_data['Temperature'], game_data['EstimatedCondition'], 'o')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-5c97387c7ca3> in <module>
# ----> 1 plt.plot(game_data['Temperature'], game_data['EstimatedCondition'], 'o')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
# ...
